# %% [raw]
# To split on one feature (sorting): m log (m)
#
# to split on n features = n * m log m
#
# to split again and again = height * n * m log m
#
# height in worst case: m
# best case scenrio, height = log (m)
#
# best case scenerio - perfectly balanced tree - complexity -  * n * m (log m)^2
#
# worst case - m * n * m * log m = n * m^2 * log (m)
# ----
#
# # class tree_node:
#     - left : tree_node
#     - right: tree_node
#     - decision_boundary # column_name
#     - decision_boundary_value # value of the column
#     - labels
#
# def split_data(X, y):
#     for column in X.columns:
#         #sort column
#         find best split in that column
#     split the instances best on the best column and best value
#     return split
#
# def prepare_tree(X, y):
#     if len(X) <= 1:
#         return None
#     column_name, column_val, X_left, y_left, X_right, y_right = split_data(X, y)
#     left_tree = prepare_tree(X_left, y_left)
#     right_tree = prepare_tree(X_right, y_right)
#     new tree_node(left_tree, right_tree, column_name, column_val)
#
# # IRIS - Versicolor
#
# arr = [1,2 | 10, 12, 13]
#
#     1,2, 10 |  12, 13
# find the best split.

# %%
def find_variance(arr):
    print(arr)
    mean = np.mean(arr)
    print(mean)
    return sum((arr - mean)**2)

# %%
import numpy as np
arr = np.array([1,2, 10, 12])
find_variance(arr[:2])
# Out:
# [1 2]
# 1.5
# np.float64(0.5)

# %%
find_variance(arr[2:])
# Out:
# [10 12]
# 11.0
# np.float64(2.0)

# %%
find_variance(arr[1:3])
# Out:
# [ 2 10]
# 6.0
# np.float64(32.0)

# %%
def weight_variance(arr_left, arr_right):
    #

# %%
def find_best_split(arr):
    for i in range(1, len(arr)):
        ...

# %%
prob = [.1, .2, .7] # #3 colors 3 R, 3 B, 4 Y
prob1 = [.3, .3, .4] #3 colors 3 R, 3 B, 4 Y

.1*.2*.7, .3*.3*.4
# Out:
# (0.014000000000000002, 0.036)

# %%
# 3 classes p1, p2, p3
# p1*p2*p3
1/3 * 1/3 * 1/3

n**n * p1 * p2 * p3
# Out:
# 0.972

# %%
from collections import Counter
c = Counter(['A','B', 'C'])

# %%
for k, v in c.items():
    print(k, v)
# Out:
# A 1
# B 1
# C 1

# %%
def impurity(elements):
    #

# %%
# Entropy
import math 

def impurity(probs):
    entropy = 0
    for p in probs:
        entropy -= p * math.log2(p)
    return entropy

# %%
impurity([.5, .5]), impurity([1e-9, 1]), impurity([0.2, .8])
# Out:
# (1.0, 2.9897352853986267e-08, 0.7219280948873623)
