# %%
def errorf(y_pred):
    y_actual = 2
    diff = abs(y_actual - y_pred)
    if diff > 2:
        return diff
    else:
        return diff * diff


def errorf(y_pred):
    y_actual = 2
    diff = abs(y_actual - y_pred)

    if diff > 2:
        return diff
    else:
        return diff * diff

# %%
import numpy as np

y_pred = points = np.linspace(-8, 12, 10000)
error = []
for yp in y_pred:
    error.append(errorf(yp))

# %%
errors = np.array(error)

# %%
import matplotlib.pyplot as plt

yparr = np.array(y_pred)
plt.scatter(yparr, error)

# %%
eps = 1e-8
def gradient(f, x):
    return (f(x + eps) - f(x))/eps

# %%
grads = []
for yp in y_pred:
    g = gradient(errorf, yp)
    grads.append(g)

grads = np.array(grads)
plt.scatter(yparr, grads)

# %%
y = A * abs(diff) + B, diff > d # when value is at 0.

y = diff*diff, when diff <= d 

# at diff == d both functions should have same slope and same value.

d > 0

A * d + B = d*d 
A = 2 * d 
B = - d*d 


d < 0
- A * d + B = d*d 
- A = 2d
B = - d * d 

y = 2 * d * abs(diff) - d*d

# %% [markdown]
# 1. End to End project - regression
# 1. Agentic Harness
# 2. Implementing a simple gradient descent - single variable / feature
# 3. End to end project - classification
# 4. Take - Iris dataset and build your own classifier
#     * gradient descent
#     * Sigmoid -> MSE

# %%
# Built a binary classifier
Can you use binary classifier to do multiclass
Digit ->M0 -> 0 or not 0
Digit ->M1 -> 1 or not-1
Digit -> M2 -> 2 or not-2
Digit -> M3 -> 3 or not 3

...
digit -> m
