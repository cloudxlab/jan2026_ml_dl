# %%
# https://www.tbench.ai/benchmarks/terminal-bench-2

# %% [markdown]
# 1. Agent Loop (for _ in range(max_loop))
# 2. Core Tools: AnswerUSER, AskCLarificationQuestion
# 2. Context compression
# 3. Dynamically looking up text to augment prompt (RAG)
# 4. External Tool calling / MCP
# 5. Python Code Execution
# 6. Running Unix Commands
# 7. Memory: saving the results into file and maintain a list of files.
# 8. SubAgent
# 9. Past history of all conversations

# %%
# def answer_question(question):
#     context = ''
#     for _ in range(200):
#         prompt = f'''
#         You are an intelligent agent. 
#         Before starting the work, plan.
#         UserQuestion: {question}
#         if a task is huge break it into subtasks:
#         SUBTASK: <question>
#          '''
#         if len(context) != 0:
#             prompt += f'Context so far: {context}'
        
#         answer = llm_answer(prompt)
#         if answer.name == "SUBTASK":
#             result = answer_question(answer.value)
#             context += result

# %%
Prompt = '''
You are such and such...


<<Memory>>

<task1 - result>
<task2 - result>
...

'''
