# %% [raw]
# To fit perfectly
#     two datapoints => y = mx + c (2)
#     three datapoints => y = ax^2 + bx + c (3)
#     Four data points => y = ax^3 + bx^2 + cx + d (4)
#     five data points => y = ax^4 + bx^3 + cx^2 + dx + e(5)

# %% [raw]
# E = 10*a^2 - 4a + 5
#
# At what value of a would we achieve minimum E.

# %%
def E_func(a):
    return 10*a**2 - 4*a + 5

# %%
E_func(10)
# Out:
# 965

# %%
eps = 1e-8
a = 10
(E_func(a+eps) - E_func(a))/eps
# Out:
# 196.00001905928366

# %%
eps = 1e-8
a = 5
(E_func(a+eps) - E_func(a))/eps
# Out:
# 95.99999941656279

# %%
eps = 1e-8
a = 1
(E_func(a+eps) - E_func(a))/eps
# Out:
# 15.999999902760464

# %%
eps = 1e-8
a = -1
(E_func(a+eps) - E_func(a))/eps
# Out:
# -23.999999854140697

# %%
eps = 1e-8
a = 0
(E_func(a+eps) - E_func(a))/eps
# Out:
# -3.999999886872274

# %%
eps = 1e-8
a = .5
(E_func(a+eps) - E_func(a))/eps
# Out:
# 6.000000141170858

# %%
eps = 1e-8
a = .25
(E_func(a+eps) - E_func(a))/eps
# Out:
# 1.000000082740371

# %%
eps = 1e-8
a = .1
(E_func(a+eps) - E_func(a))/eps
# Out:
# -1.999999899027216

# %%
eps = 1e-8
a = .2
(E_func(a+eps) - E_func(a))/eps
# Out:
# 1.7763568394002505e-07

# %%
eps = 1e-8
a = .21
(E_func(a+eps) - E_func(a))/eps
# Out:
# 0.20000010536591617

# %%
def E_func(a):
    return 13*a**2 - 10*a + 50

# %%
eps = 1e-8
a = .21
(E_func(a+eps) - E_func(a))/eps
# Out:
# -4.5400000203699165

# %%
eps = 1e-8
a = .25
(E_func(a+eps) - E_func(a))/eps
# Out:
# -3.4999999343199306

# %%
eps = 1e-8
a = 50
(E_func(a+eps) - E_func(a))/eps
# Out:
# 1289.9996363557875

# %%
eps = 1e-8
a = 0
(E_func(a+eps) - E_func(a))/eps
# Out:
# -10.000000116860974

# %%
eps = 1e-8
a = 25
(E_func(a+eps) - E_func(a))/eps
# Out:
# 640.0000529538374

# %%
eps = 1e-8
a = 12
(E_func(a+eps) - E_func(a))/eps
# Out:
# 302.0000121978228

# %%
eps = 1e-8
a = 6
(E_func(a+eps) - E_func(a))/eps
# Out:
# 146.00000213249587

# %%
eps = 1e-8
a = 3
(E_func(a+eps) - E_func(a))/eps
# Out:
# 67.99999994200334

# %%
eps = 1e-8
a = 1.5
(E_func(a+eps) - E_func(a))/eps
# Out:
# 29.00000026784255

# %%
eps = 1e-8
a = .75
(E_func(a+eps) - E_func(a))/eps
# Out:
# 9.500000430762157

# %%
eps = 1e-8
a = .35
(E_func(a+eps) - E_func(a))/eps
# Out:
# -0.899999719194966

# %%
eps = 1e-8
a = .5
(E_func(a+eps) - E_func(a))/eps
# Out:
# 3.000000248221113

# %%
eps = 1e-8
a = .4
(E_func(a+eps) - E_func(a))/eps
# Out:
# 0.4000000330961484

# %%
eps = 1e-8
a = .375
(E_func(a+eps) - E_func(a))/eps
# Out:
# -0.2500001983207767

# %%
eps = 1e-8
a = .385
(E_func(a+eps) - E_func(a))/eps
# Out:
# 0.01000017846308765

# %%
eps = 1e-8
a = .3849
(E_func(a+eps) - E_func(a))/eps
# Out:
# 0.0074003025929414434

# %%
eps = 1e-8
a = .3848
(E_func(a+eps) - E_func(a))/eps
# Out:
# 0.004799716180059477

# %%
eps = 1e-8
a = .38465
(E_func(a+eps) - E_func(a))/eps
# Out:
# 0.0008995471034722868

# %%
eps = 1e-8
a = .38463
(E_func(a+eps) - E_func(a))/eps
# Out:
# 0.0003801403636316536

# %% [raw]
# # Write a function
#
# def find_minimum(E_func):
#     # Returns value of a at which E_func is minimum
#     # E_func takes only one param
#     # E_func is also a convex function i.e U  shape.

# %%
def E_func(a):
    return 13*a**2 - 10*a + 50

# find_minimum(E_func)

# %%
def E_func1(a, b): # Example
    return (2*a + b - 10)**2 + (3*a + b - 30)**2 # w0, w1, w2, w3....

def find_minimum(E_func1):
    # Returns value of a at which E_func1 is minimum
    # E_func1 takes two params
    # E_func1 is also a convex function wr to both a, b i.e U  shape. 
    pass

# %%
def find_minimum(E_func1, n_params):
    # Returns value of a at which E_func1 is minimum
    # E_func1 takes any number of n_params params
    # E_func1 is also a convex function wr to both a, b i.e U  shape. 
    pass

# %% [raw]
# Next Steps:
# - Build a RAG)
# - Build toolcall/agent
# - Build End to end project - regression + classification (Beginner friend playlist - LMS)
