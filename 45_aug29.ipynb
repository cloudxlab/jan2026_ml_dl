# %%
def impurity(r, b):
    return (1 - abs(b - r))

# %%
impurity(.5, .5)
# Out:
# 1.0

# %%
impurity(0, 1)
# Out:
# 0

# %%
impurity(1, 0)
# Out:
# 0

# %%
impurity(0.2, .8)
# Out:
# 0.3999999999999999

# %%
impurity(0.1, .9)
# Out:
# 0.19999999999999996

# %%
impurity(0.3, .7)
# Out:
# 0.6000000000000001

# %%
impurity(0.4, .6)
# Out:
# 0.8

# %%
def impurity_m(r, b):
    return (1 - abs(b - r))

# %%
def impurity_a(r, b):
    return 4*r*b #(1 - (b - r)**2)

# %%
import numpy as np
for r in np.arange(0, 1.1, .1):
    b = 1 - r
    print(f"r: {r}, b:{b}, Impurity: M:{impurity_m(r, b)}, A: {impurity_a(r, b)}")
# Out:
# r: 0.0, b:1.0, Impurity: M:0.0, A: 0.0
# r: 0.1, b:0.9, Impurity: M:0.19999999999999996, A: 0.36000000000000004
# r: 0.2, b:0.8, Impurity: M:0.3999999999999999, A: 0.6400000000000001
# r: 0.30000000000000004, b:0.7, Impurity: M:0.6000000000000001, A: 0.8400000000000001
# r: 0.4, b:0.6, Impurity: M:0.8, A: 0.96
# r: 0.5, b:0.5, Impurity: M:1.0, A: 1.0
# r: 0.6000000000000001, b:0.3999999999999999, Impurity: M:0.7999999999999998, A: 0.96
# r: 0.7000000000000001, b:0.29999999999999993, Impurity: M:0.5999999999999999, A: 0.8399999999999999
# r: 0.8, b:0.19999999999999996, Impurity: M:0.3999999999999999, A: 0.6399999999999999
# r: 0.9, b:0.09999999999999998, Impurity: M:0.19999999999999996, A: 0.35999999999999993
# r: 1.0, b:0.0, Impurity: M:0.0, A: 0.0
