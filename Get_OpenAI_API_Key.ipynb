# %% [markdown]
# # How To Get OpenAI API Key

# %% [markdown]
# ## Step 1:
# Visit this link: https://platform.openai.com/api-keys

# %% [markdown]
# ## Step 2:
# <img src="./openai_1.png"><br>

# %% [markdown]
# ## Step 3:
# <img src="./openai_2.png" width="500px"><br>

# %% [markdown]
# ## Step 4:
# <img src="./openai_3.png" width="500px"><br>

# %% [markdown]
# ## Step 5:
# Visit this link: https://platform.openai.com/settings/organization/billing/overview

# %% [markdown]
# ## Step 6:
# <img src="./openai_4.png" width="600px"><br>

# %% [markdown]
# ## Step 7:
# <img src="./openai_5.png" width="500px"><br>

# %% [markdown]
# ## Step 8:
# <img src="./openai_6.png" width="500px"><br>

# %% [markdown]
# ## Step 9:
# <img src="./openai_7.png" width="500px">

# %% [markdown]
# ## Step 10: Back to the RAG Implementation
#
# [How to get OpenAI API Key](./18_April_2026_RAG_System.ipynb)
